# %%
import pandas as pd
data_dir = "../data/IoT_Indoor_Air_Quality_Dataset.csv"

df = pd.read_csv(data_dir)
print(df.shape)
print(df.columns)
print(df.head())
print(df.describe().T)
# Out:
# (97458, 12)
# Index(['Timestamp', 'Temperature (?C)', 'Humidity (%)', 'CO2 (ppm)',
#        'PM2.5 (?g/m?)', 'PM10 (?g/m?)', 'TVOC (ppb)', 'CO (ppm)',
#        'Light Intensity (lux)', 'Motion Detected', 'Occupancy Count',
#        'Ventilation Status'],
#       dtype='object')
#           Timestamp  Temperature (?C)  Humidity (%)  CO2 (ppm)  PM2.5 (?g/m?)  \
# 0  18-02-2024 08:00             21.75         63.11     989.74          31.17
# 1  18-02-2024 08:05             27.51         68.03     924.59          27.32
# 2  18-02-2024 08:10             25.32         53.51     604.05          73.84
# 3  18-02-2024 08:15             23.99         58.52     692.20          62.94
# 4  18-02-2024 08:20             19.56         69.34     533.12          26.56
#
#    PM10 (?g/m?)  TVOC (ppb)  CO (ppm)  Light Intensity (lux)  Motion Detected  \
# 0         89.66      226.83      2.84                 646.86              0.0
# ...
